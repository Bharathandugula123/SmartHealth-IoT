# %% [markdown]
# # SmartHealth-IoT Colab Implementation
# Run the project pipeline after uploading this repository to Colab or Drive.

# %%
# !pip install -q numpy pandas scikit-learn matplotlib joblib PyYAML psutil lightgbm xgboost streamlit plotly

# %%
# %cd /content/SmartHealth-IoT
# !python main.py
